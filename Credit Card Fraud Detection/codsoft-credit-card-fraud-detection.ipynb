# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
data=pd.read_csv("/kaggle/input/creditcardfraud/creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data=data.drop_duplicates()

# %%
x=data.drop("Class",axis=1)
y=data["Class"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=101)

# %%
smote = SMOTE(random_state=101)
xtrainsmote, ytrainsmote = smote.fit_resample(xtrain, ytrain)

# %%
xtrainsmote.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0   41110.0  1.360170 -0.105120 -0.026442 -0.246305 -0.375191 -0.726283
# 1  117430.0 -0.144263  0.989749 -0.658424 -0.765560  1.044936 -0.408662
# 2   30637.0 -0.375379  0.976726  1.340372 -0.141541  0.095680 -0.633842
# 3  165836.0  2.275658 -0.625857 -1.747002 -1.164417  0.120648 -0.503048
# 4  164283.0 -5.943253  4.895733 -4.256435 -1.647317 -1.172500 -2.153876
#
#          V7        V8        V9  ...       V20       V21       V22       V23  \
# 0 -0.163242 -0.081611  0.581652  ... -0.161762 -0.186852 -0.598759 -0.034795
# 1  0.707224  0.147879  0.119354  ...  0.069819 -0.362937 -0.922522  0.052104
# 2  0.634357  0.014203 -0.231337  ...  0.055395 -0.271365 -0.756375 -0.076125
# 3 -0.302738 -0.340158 -0.688982  ...  0.095707  0.401617  1.213436 -0.074032
# 4 -0.232372  1.346291  2.520441  ...  0.767148 -0.126537  0.353528  0.339498
#
#         V24       V25       V26       V27       V28  Amount
# ...

# %%
ytrainsmote.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
models={"Decision Tree":DecisionTreeClassifier(),
"K Neighbors":KNeighborsClassifier(),
"Random Forest Classifier":RandomForestClassifier()}

# %%
for name, model in models.items():
    model.fit(xtrainsmote, ytrainsmote)
    ypredict = model.predict(xtest)
    acc=accuracy_score(ytest,ypredict)
    print(f"\nClassifier: {name}")
    print("-----------------------------------------------------")
    print("Accuracy : ",round(acc*100,2))
    print("Classification Report :")
    print(classification_report(ytest, ypredict))
    print("\n Confusion Matrix :")
    print(confusion_matrix(ytest, ypredict))
    print("=====================================================")
# Out:
# Classifier: Decision Tree
# -----------------------------------------------------
# Accuracy :  99.78
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56657
#            1       0.40      0.82      0.53        89
#
#     accuracy                           1.00     56746
#    macro avg       0.70      0.91      0.77     56746
# weighted avg       1.00      1.00      1.00     56746
#
#
#  Confusion Matrix :
# [[56546   111]
#  [   16    73]]
# ...
#
# Classifier: K Neighbors
# -----------------------------------------------------
# Accuracy :  94.51
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97     56657
#            1       0.01      0.44      0.02        89
#
#     accuracy                           0.95     56746
#    macro avg       0.51      0.69      0.50     56746
# ...

# %% [markdown]
# # **Conclusion**
# > **Our evaluation of various classifiers for predicting credit card fraud demonstrates the superior performance of the Random Forest Classifier. With an accuracy of 99.96%, it outperforms both the Decision Tree and K Neighbors classifiers. The Random Forest Classifier also maintains high precision and recall rates of 0.89 and 0.82, respectively, for detecting frauds, resulting in an impressive f1-score of 0.85. In comparison, while the Decision Tree achieved an accuracy of 99.78%, its ability to detect faults was less effective, with a recall of 0.8 and a lower f1-score of 0.53. The K Neighbors classifier, with an accuracy of 94.51%, struggled significantly with fraud detection, achieving a recall of only 0.44 and an f1-score of 0.02. These results suggest that the *Random Forest Classifier* is the most reliable model for *credit card fraud detection*, offering a balanced performance in terms of accuracy, precision, and recall.**
